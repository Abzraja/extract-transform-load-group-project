# %%
# import depdencies
import pandas as pd
from sqlalchemy import create_engine, inspect
from config import username, password

# %%
#import data
final_merged_data = pd.read_csv("Resources/Final_Merged_Data.csv")
final_merged_data
# Out:
#         country  year  litres_per_capita_average  happiness_score  \
# 0     Lithuania  2015                       15.4            5.833
# 1       Estonia  2015                       14.4            5.429
# 2        Latvia  2019                       13.2            5.940
# 3       Germany  2015                       13.0            6.750
# 4        Uganda  2015                       13.0            3.931
# ..          ...   ...                        ...              ...
# 259  Bangladesh  2019                        0.0            4.456
# 260  Mauritania  2015                        0.0            4.436
# 261  Mauritania  2019                        0.0            4.490
# 262  Bangladesh  2015                        0.0            4.694
# 263      Kuwait  2019                        0.0            6.021
#
#      gdp_per_capita  healthy_life_expectancy
# 0           1.14723                  0.73128
# 1           1.15174                  0.77361
# ...

# %%
# Create connection
conn_string = f"postgresql://{username}:{password}@localhost:5432/alcohol_vs"
engine = create_engine(conn_string)

# Confirm tables
inspect(engine).get_table_names()
# Out:
# ['alcohol_vs']

# %%
# load data into Postgre SQL table
final_merged_data.to_sql(name="alcohol_vs", con=engine, if_exists='append', index=False)
